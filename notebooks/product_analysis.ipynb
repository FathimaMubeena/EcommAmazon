# %% [markdown]
# # Analysis of Product

# %% [markdown]
# Read CSV file Products

# %%
import pandas as pd

products_dataframe = pd.read_csv("/Users/fatimamubeenshaik/IdeaProjects/EcommAmazon/data/products.csv")
products_dataframe
# Out:
#     1001                   Bottled Water       Beverages  \
# 0   1002                    Soda (12 oz)       Beverages
# 1   1003                 Chips (Classic)          Snacks
# 2   1004                   Chocolate Bar          Snacks
# 3   1005                    Granola Bars          Snacks
# 4   1006                          Banana          Fruits
# 5   1007                           Apple          Fruits
# 6   1008                      Toothpaste   Personal Care
# 7   1009                         Shampoo   Personal Care
# 8   1010          Toilet Paper (4 rolls)       Household
# 9   1011            Cereal (Corn Flakes)       Breakfast
# 10  1012                 Milk (1 Gallon)           Dairy
# 11  1013                    Eggs (Dozen)           Dairy
# 12  1014                  Coffee (12 oz)       Beverages
# 13  1015                     Gummy Bears           Candy
# 14  1016          Paper Towels (2 rolls)       Household
# ...

# %%
# adding column name to the respective columns
products_dataframe.columns =["product_id", "product_name", "category", "description", "price","quantity","freeshiping"]
products_dataframe
# Out:
#     product_id                    product_name        category  \
# 0         1002                    Soda (12 oz)       Beverages
# 1         1003                 Chips (Classic)          Snacks
# 2         1004                   Chocolate Bar          Snacks
# 3         1005                    Granola Bars          Snacks
# 4         1006                          Banana          Fruits
# 5         1007                           Apple          Fruits
# 6         1008                      Toothpaste   Personal Care
# 7         1009                         Shampoo   Personal Care
# 8         1010          Toilet Paper (4 rolls)       Household
# 9         1011            Cereal (Corn Flakes)       Breakfast
# 10        1012                 Milk (1 Gallon)           Dairy
# 11        1013                    Eggs (Dozen)           Dairy
# 12        1014                  Coffee (12 oz)       Beverages
# 13        1015                     Gummy Bears           Candy
# ...

# %%
products_dataframe.product_id
# Out:
# 0     1002
# 1     1003
# 2     1004
# 3     1005
# 4     1006
# 5     1007
# 6     1008
# 7     1009
# 8     1010
# 9     1011
# 10    1012
# 11    1013
# 12    1014
# 13    1015
# 14    1016
# 15    1017
# 16    1018
# 17    1019
# 18    1020
# 19    1021
# 20    1022
# 21    1023
# 22    1024
# 23    1025
# 24    1026
# 25    1027
# 26    1028
# 27    1029
# 28    1030
# 29    1031
# 30    1032
# 31    1033
# 32    1034
# 33    1035
# 34    1036
# 35    1037
# 36    1038
# 37    1039
# 38    1040
# 39    1041
# 40    1042
# 41    1043
# 42    1044
# 43    1045
# 44    1046
# 45    1047
# 46    1048
# 47    1049
# 48    1050
# Name: product_id, dtype: int64

# %%
# mysql> select count(*), category FROM products group by category;

products_dataframe.groupby('category').count()
# Out:
#                 product_id  product_name  description  price  quantity  \
# category
#  Beverages              12            12           12     12        12
#  Breakfast               1             1            1      1         1
#  Candy                   1             1            1      1         1
#  Condiments              1             1            1      1         1
#  Dairy                   2             2            2      2         2
#  Frozen Foods            1             1            1      1         1
#  Fruits                  2             2            2      2         2
#  Household               3             3            3      3         3
#  Personal Care          12            12           12     12        12
#  Snacks                 14            14           14     14        14
#
#                 freeshiping
# category
#  Beverages               12
#  Breakfast                1
#  Candy                    1
#  Condiments               1
# ...
